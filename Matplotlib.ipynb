# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.random.rand(50)

# %%
y = np.random.rand(50)

# %%
x
# Out:
# array([0.61427883, 0.62339424, 0.75138902, 0.10904949, 0.86541822,
#        0.85036069, 0.00195843, 0.61461236, 0.43467432, 0.7851154 ,
#        0.74372709, 0.17763261, 0.82698359, 0.68423046, 0.43022486,
#        0.80019979, 0.57907919, 0.27396542, 0.65318059, 0.35912869,
#        0.69721964, 0.00325884, 0.22886908, 0.96187681, 0.23607089,
#        0.98904685, 0.68220678, 0.08700779, 0.534044  , 0.67139373,
#        0.6164587 , 0.82893769, 0.4351945 , 0.495356  , 0.26189267,
#        0.83456716, 0.75182087, 0.03632383, 0.95487756, 0.17659397,
#        0.66303753, 0.76598794, 0.45032591, 0.29096882, 0.25765942,
#        0.04038048, 0.16481501, 0.61013178, 0.20170777, 0.32132373])

# %%
y
# Out:
# array([0.57050851, 0.35122774, 0.64204006, 0.89826604, 0.14722612,
#        0.89298256, 0.64977477, 0.18322607, 0.93756422, 0.59707411,
#        0.79432905, 0.37868863, 0.54329917, 0.2349149 , 0.58861639,
#        0.06980049, 0.94974794, 0.89348759, 0.09274289, 0.88704276,
#        0.91825221, 0.03558106, 0.34770053, 0.08345688, 0.70618557,
#        0.17880694, 0.88510255, 0.14804134, 0.58071075, 0.89328488,
#        0.02934761, 0.28591916, 0.09917453, 0.876442  , 0.76002688,
#        0.3579763 , 0.07725167, 0.81803469, 0.39038199, 0.52951819,
#        0.80726159, 0.19893117, 0.48432791, 0.92258555, 0.78538404,
#        0.84518385, 0.48296815, 0.43874701, 0.85192436, 0.57472009])

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize = (6,2))
plt.scatter(x,y , c='r' , alpha = 0.4 , marker = 'X')
plt.xlabel("This is my X axis")
plt.ylabel("This is my Y axis")
plt.title("Thi sis my XY")

plt.grid()

# %%
x = np.linspace(1,10 , 100)
y = np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
#         6.90909091,  7.        ,  7.09090909,  7.18181818,  7.27272727,
#         7.36363636,  7.45454545,  7.54545455,  7.63636364,  7.72727273,
#         7.81818182,  7.90909091,  8.        ,  8.09090909,  8.18181818,
#         8.27272727,  8.36363636,  8.45454545,  8.54545455,  8.63636364,
#         8.72727273,  8.81818182,  8.90909091,  9.        ,  9.09090909,
#         9.18181818,  9.27272727,  9.36363636,  9.45454545,  9.54545455,
#         9.63636364,  9.72727273,  9.81818182,  9.90909091, 10.        ])

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
#         0.58583144,  0.6569866 ,  0.72271585,  0.78247636,  0.83577457,
#         0.88217031,  0.92128041,  0.95278186,  0.9764145 ,  0.99198316,
#         0.99935926,  0.99848187,  0.98935825,  0.97206374,  0.94674118,
#         0.9135997 ,  0.87291301,  0.82501713,  0.77030762,  0.70923631,
#         0.64230758,  0.57007418,  0.49313267,  0.41211849,  0.32770071,
#         0.24057653,  0.15146548,  0.06110351, -0.0297631 , -0.1203839 ,
#        -0.21001048, -0.29790263, -0.38333447, -0.46560043, -0.54402111])

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y , c='r')

# %%
plt.plot(x,y,'--r')
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.grid()

# %%
x = ['a','b','c','d','e']
y = np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.39014458, 0.09224365, 0.81763308, 0.81862711, 0.88357342])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
x = [3,4,5,6,7,8]
y = [4,5,6,7,8,9]

# %%
plt.plot(x,y)

# %%
plt.figure(figsize = (6,3))
plt.scatter(x,y)

# %%
data = [1,2,3,4,5,6,6,6,6,7,7,7,8,8,9,8,8,9,9,9]

# %%
plt.figure(figsize = (6,3))
plt.hist(data)
# Out:
# (array([1., 1., 1., 1., 0., 1., 4., 3., 4., 4.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)

# %%
x
# Out:
# array([0.99879757, 0.60263662, 0.00208747, 0.09717268, 0.26324572,
#        0.4222318 , 0.51326711, 0.82785434, 0.5740707 , 0.12331952,
#        0.54270492, 0.05131594, 0.98920603, 0.25850237, 0.55223896,
#        0.66961079, 0.56842474, 0.02404826, 0.80421537, 0.23848395,
#        0.01651078, 0.77480957, 0.00818093, 0.26286882, 0.24102364,
#        0.93220505, 0.04102103, 0.39341561, 0.89711429, 0.54193745,
#        0.10364168, 0.43751239, 0.70292801, 0.33803419, 0.87937123,
#        0.98596001, 0.10482429, 0.01549569, 0.82470606, 0.75485933,
#        0.84631181, 0.32095317, 0.33626723, 0.48008475, 0.28605742,
#        0.66999658, 0.19005445, 0.87177778, 0.12390275, 0.11879107])

# %%
y
# Out:
# array([0.3638721 , 0.26559322, 0.24432061, 0.03209069, 0.61262632,
#        0.15592345, 0.25285937, 0.41155563, 0.43309648, 0.30099359,
#        0.55414275, 0.00864884, 0.09847972, 0.50801711, 0.46737078,
#        0.54899014, 0.26658163, 0.79161863, 0.97256164, 0.40433622,
#        0.59766407, 0.49403763, 0.43905247, 0.71245408, 0.94683383,
#        0.06124871, 0.4461265 , 0.33142187, 0.22545871, 0.172335  ,
#        0.32585641, 0.96815863, 0.68889798, 0.64558027, 0.29826632,
#        0.71716215, 0.22613006, 0.25629877, 0.5136243 , 0.39450937,
#        0.55090186, 0.37205531, 0.609521  , 0.08394392, 0.40401545,
#        0.94137524, 0.00866759, 0.64201345, 0.6927197 , 0.53213978])

# %%
z
# Out:
# array([0.64611135, 0.02307653, 0.15418828, 0.47530883, 0.32918172,
#        0.42571921, 0.90177835, 0.70313066, 0.88013884, 0.3999701 ,
#        0.10307045, 0.79218543, 0.87431134, 0.94577384, 0.42020709,
#        0.02512587, 0.77150253, 0.13921436, 0.00257645, 0.19343064,
#        0.69377561, 0.91180734, 0.29558334, 0.99520218, 0.32380002,
#        0.03089233, 0.19429494, 0.05005903, 0.89267014, 0.88675003,
#        0.76644291, 0.61123401, 0.61750151, 0.11009597, 0.13016301,
#        0.69986053, 0.25008404, 0.6406482 , 0.67899995, 0.73368237,
#        0.62224827, 0.14609436, 0.93147319, 0.95481213, 0.9745079 ,
#        0.2797144 , 0.47684999, 0.5636374 , 0.70330813, 0.84416447])
